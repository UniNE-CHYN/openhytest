# %% [markdown]
# # Theis (1935) constant head boundary model
#
# This notebook demonstrates how to use **OpenHyTest** for the interpretation of a pumping test in a confined aquifer with the Theis (1941) constant head boundary model.
#
# Copyright 1998-2022 - Nathan Dutler, Bernard Brixel & Philippe Renard
#
# The data set for this example has been provided by:
# G. de Marsily, cours DEA Paris 6, "Aquifère cétier de Nefza, Tunisie".
# Piezometer A3Bis
#
# First, we append the openhytest folder to the system path using the 'sys' library and import than the 'openhytest' library as ht.

# %%
# %matplotlib inline
import sys
sys.path.append("..")
import openhytest as ht
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
# Out:
# /Users/nathan/Desktop/openhytest/notebooks/../openhytest/modelclasses.py:2502: SyntaxWarning: invalid escape sequence '\s'
#   ax.loglog(td, sd, '-', color=color, label= '$\sigma$ = {}'.format(sigma[i]))
# /Users/nathan/Desktop/openhytest/notebooks/../openhytest/modelclasses.py:2506: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('$\lambda$ = {}'.format(landa))
# /Users/nathan/Desktop/openhytest/notebooks/../openhytest/modelclasses.py:2525: SyntaxWarning: invalid escape sequence '\l'
#   ax.loglog(td, sd, '-', color=color, label= '$\lambda$ = {}'.format(landa[i]))
# /Users/nathan/Desktop/openhytest/notebooks/../openhytest/modelclasses.py:2529: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('$\sigma$ = {}'.format(self.sigma))
# /Users/nathan/Desktop/openhytest/notebooks/../openhytest/modelclasses.py:2954: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('$\sigma$')
# /Users/nathan/Desktop/openhytest/notebooks/../openhytest/modelclasses.py:2978: SyntaxWarning: invalid escape sequence '\p'
#   plt.title('$\phi$')

# %% [markdown]
# ## Load the data
#
# The diagnostic plot shows a behavior that indicates a possible constant head boundary effect.

# %%
data = pd.read_csv('../data/thc_ds1.txt', header=None,sep=" ",names=['t','s'], dtype={'t': 'float64', 's': 'float64'})
test = ht.preprocessing(data)
test.diagnostic()

# %% [markdown]
# ## Model
#
# 1) We initialize the Theis constant head boundary model with 0.030 m^3/s and radius of 20 m and show first the typecurve for different radii.
#
# 2) Then a first model parameter guess is done and showing the results with the trial function.

# %%
model = ht.Theis_constanthead(Q=0.03,r=20, df=data)
model.plot_typecurve()

# %%
p = model.guess_params()
print("estimated parameter vector:",p)
model.trial()
# Out:
# estimated parameter vector: [6.22576096e-01 4.76664633e+01 7.62562843e+04]
# T =  0.008829470041817385 m2/s
# S =  0.002363013878601242 -

# %% [markdown]
# Let use proceed with the automatic fit and directly report the results of the interpretation.

# %%
model.rpt(fitmethod='lm', ttle='Theis (1935) const. head', author='openhytest Developer', filetype='pdf', reptext='Report_Theis_consthead_example')
# Out:
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 1.0579e+00, final cost 9.9037e-02, first-order optimality 6.90e-08.

# %% [markdown]
# The estimated transmissivity is 8.7e-3 m2/s, the storativity is 2.7e-3, and the distance to the image well is 1105 m. These numbers are close to the estimation provided by de Marsily.
#
# T  = 8.4 e-3 [m2/s]
#
# S  = 2.8 e-3
#
# ri = 1050 m

# %% [markdown]
# ## Laplace inversion
#
# First, let us try the laplace solution and inversion for the drawdown and the derivative.
# Then we, compare the solution with the direct calculalted drawdown and derivative using mean residuals, standard deviation and RMS.

# %%
import matplotlib.pyplot as plt
td = np.logspace(-2, 5)
sd = model._laplace_drawdown(td, inversion_option='dehoog')
plt.loglog(td, sd)
dd = model._laplace_drawdown_derivative(td, inversion_option='dehoog')
plt.loglog(td, dd)
plt.xlabel('$t_D / r_D^2$')
plt.ylabel('$s_D$')
plt.xlim((1e-2, 1e5))
plt.ylim((1e-2, 20))
plt.grid('True')

# %%
sd2 = model.dimensionless(td)
residual = sd-sd2

mr = np.mean(residual) #mean resiudal
print(mr)
sr = 2 * np.std(residual) #standard deviation
print(sr)
rms = np.sqrt(np.mean(residual**2))
print(rms)
# Out:
# 4.687470540048001e-09
# 2.502113546987324e-08
# 1.3359890909519251e-08

# %%
dd2 = model.dimensionless_logderivative(td)
residual2 = dd-dd2

mr2 = np.mean(residual2) #mean resiudal
print(mr2)
sr2 = 2 * np.std(residual2) #standard deviation
print(sr2)
rms2 = np.sqrt(np.mean(residual2**2))
print(rms2)
# Out:
# 7.904606940751069e-10
# 5.820069086939862e-09
# 3.015481578963126e-09
