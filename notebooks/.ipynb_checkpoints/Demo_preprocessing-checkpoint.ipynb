# %% [markdown]
# # Demonstration of preprocessing tools implemented in the openhytest
#
# Copyright 2019 - Openhytest Developer
#
# ## Load the data

# %%
import pandas as pd
import openhytest as ht
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-63bfe9ba648b> in <module>
#       1 import pandas as pd
# ----> 2 import openhytest as ht
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'openhytest'

# %% [markdown]
# The interpetation is made in three steps: (1) load the data, (2) adjust a straight line to the late part of the data set (here we take the points from the 3rd to the last), (3) report the results.

# %%
name = ["t","s"]
dtypes = {'t': 'float', 's': 'float'}
data = pd.read_csv('data/ths_ds1.txt', sep=" ", header = None, names=name, dtype=dtypes)
plt.plot(data.t,data.s)
ht.diagnostic(data.t,data.s)

# %%
p = hp.jcb.gss(data.t,data.s) 
q = 0.013888                     # pumping rate in m3/s
r = 250                          # distance to the well in  m

# %%
hp.jcb.rpt(p,data.t,data.s,q,r,'Saddle River example with Cooper-Jacob straight line','Author')

# %% [markdown]
# We find an estimated transmissivity of 1.7e-3 m2/s and a storativity of 1.5e-5, which are identical to the values obtained by Fetter (2001) by straight line analysis (p. 174-175).
#
# Note that the same data are interpreted more precisely with the complete Theis (1941) solution in the ths_dmo example.
